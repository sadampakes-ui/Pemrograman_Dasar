# %% [markdown]
# <a href="https://colab.research.google.com/github/sadampakes-ui/Pemrograman_Dasar/blob/main/Pertemuan%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Latihan 1

tegangan = "18"
ampere = "6"
jenis_sel = "Monocrystalline"

print (tegangan)
print (ampere)
print (jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
# Latihan 2

Frequency = 50
Power_Factor = 0.8
Status_Running = True
Name = "Diesel Engine Generator"


print ((Frequency), type(Frequency))
print ((Power_Factor), type(Power_Factor))
print ((Status_Running), type(Status_Running))
print ((Name), type(Name))
# Out:
# 50 <class 'int'>
# 0.8 <class 'float'>
# True <class 'bool'>
# Diesel Engine Generator <class 'str'>

# %%
# Latihan 3

nama_unit = "PTLS Nunukan" #str
jumlah_panel = 240         #int
tegangan_keluaran = 48.5   #float
sedang_beroperasi = True   #bool

print (nama_unit, type(nama_unit))
print (jumlah_panel, type(jumlah_panel))
print (tegangan_keluaran, type(tegangan_keluaran))
print (sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PTLS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Latihan 4 list
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])
tegangan_harian.append(222.0)
print("Jumlah total data:", len(tegangan_harian))
# Out:
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7

# %%
#Latihan 5 dictionary

exhaust_fan = {
    "nama": "unit-5",
    "daya_kW" : 21,
    "tegangan_V": 50,
    "rpm": "750"
}

print("exhaust_fan:", exhaust_fan["nama"])
exhaust_fan["rpm"] = "1000"
print(exhaust_fan)
# Out:
# exhaust_fan: unit-5
# {'nama': 'unit-5', 'daya_kW': 21, 'tegangan_V': 50, 'rpm': '1000'}

# %%
#Latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print("nama unit kedua:", pembangkit[1]["nama"])
pembangkit[2]["status"] = "operasi"
pembangkit.append({"nama": "unit-4", "kapasitas_MW": 200, "status": "troubleshooting"})
print("\ndata seluruh pembangkit:")
print(pembangkit)
# Out:
# nama unit kedua: Unit-2
#
# data seluruh pembangkit:
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'unit-4', 'kapasitas_MW': 200, 'status': 'troubleshooting'}]
