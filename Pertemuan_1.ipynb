# %% [markdown]
# <a href="https://colab.research.google.com/github/sadampakes-ui/Pemrograman_Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "Rizmana Saddam Fadhilah Ikhsan"
tanggal_lahir = "05 Desember 2003"
umur = 23
tinggi = 169.5
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman'
status_lulus = False
alamat = "Puri Agung 3 Blok B2 No 6"
status = "Mahasiswa dan Karyawan Swasta"

print (nama)
print (umur)
print (tinggi)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (alamat)
print (status)
# Out:
# Rizmana Saddam Fadhilah Ikhsan
# 23
# 169.5
# RPE
# 3
# Pemerograman
# False
# Puri Agung 3 Blok B2 No 6
# Mahasiswa dan Karyawan Swasta
